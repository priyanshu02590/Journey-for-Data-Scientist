# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b936e82b-f717-4ad7-bdf5-a22449add84f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b936e82b-f717-4ad7-bdf5-a22449add84f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("ford.csv")

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df.shape
# Out:
# (17966, 9)

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.drop_duplicates()
df.shape
# Out:
# (17966, 9)

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17966.000000  17966.000000   17966.000000  17966.000000  17966.000000
# mean    2016.866470  12279.534844   23362.608761    113.329456     57.906980
# std        2.050336   4741.343657   19472.054349     62.012456     10.125696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000    9987.000000     30.000000     52.300000
# 50%     2017.000000  11291.000000   18242.500000    145.000000     58.900000
# 75%     2018.000000  15299.000000   31060.000000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17966.000000
# mean       1.350807
# std        0.432367
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17966 entries, 0 to 17965
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17966 non-null  object
#  1   year          17966 non-null  int64
#  2   price         17966 non-null  int64
#  3   transmission  17966 non-null  object
#  4   mileage       17966 non-null  int64
#  5   fuelType      17966 non-null  object
#  6   tax           17966 non-null  int64
#  7   mpg           17966 non-null  float64
#  8   engineSize    17966 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.2+ MB

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df["model"].value_counts()
# Out:
# model
#  Fiesta                   6557
#  Focus                    4588
#  Kuga                     2225
#  EcoSport                 1143
#  C-MAX                     543
#  Ka+                       531
#  Mondeo                    526
#  B-MAX                     355
#  S-MAX                     296
#  Grand C-MAX               247
#  Galaxy                    228
#  Edge                      208
#  KA                        199
#  Puma                       80
#  Tourneo Custom             69
#  Grand Tourneo Connect      59
#  Mustang                    57
#  Tourneo Connect            33
#  Fusion                     16
#  Streetka                    2
#  Ranger                      1
#  Escort                      1
#  Transit Tourneo             1
# Focus                        1
# Name: count, dtype: int64

# %%
df["transmission"].value_counts()
# Out:
# transmission
# Manual       15518
# Automatic     1361
# Semi-Auto     1087
# Name: count, dtype: int64

# %%
sns.countplot(x="transmission",data=df)
# Out:
# <Axes: xlabel='transmission', ylabel='count'>

# %%
sns.countplot(x="fuelType",data=df)
# Out:
# <Axes: xlabel='fuelType', ylabel='count'>

# %%
numeric_columns=df[["year","price","mileage","tax","mpg","engineSize"]]

# %%
df.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
for i in numeric_columns:
    plt.figure()
    sns.histplot(x=df[i],kde=True)

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(x="year",y="price",data=df)
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
sns.boxplot(x="year",y="price",data=df)
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
sns.boxplot(x="model",y="price",data=df)
# Out:
# <Axes: xlabel='model', ylabel='price'>

# %%
sns.boxplot(x="transmission",y="price",data=df)
# Out:
# <Axes: xlabel='transmission', ylabel='price'>

# %%
sns.boxplot(x="fuelType",y="price",data=df)
# Out:
# <Axes: xlabel='fuelType', ylabel='price'>

# %%
sns.boxplot(x="tax",y="price",data=df)
# Out:
# <Axes: xlabel='tax', ylabel='price'>

# %%
# Out:
# <Axes: xlabel='mpg', ylabel='price'>

# %%
sns.boxplot(x="engineSize",y="price",data=df)
# Out:
# <Axes: xlabel='engineSize', ylabel='price'>

# %%
x=df.drop(columns=["price"],axis=1)
y=df["price"]

# %%
x
# Out:
#          model  year transmission  mileage fuelType  tax   mpg  engineSize
# 0       Fiesta  2017    Automatic    15944   Petrol  150  57.7         1.0
# 1        Focus  2018       Manual     9083   Petrol  150  57.7         1.0
# 2        Focus  2017       Manual    12456   Petrol  150  57.7         1.0
# 3       Fiesta  2019       Manual    10460   Petrol  145  40.3         1.5
# 4       Fiesta  2019    Automatic     1482   Petrol  145  48.7         1.0
# ...        ...   ...          ...      ...      ...  ...   ...         ...
# 17961    B-MAX  2017       Manual    16700   Petrol  150  47.1         1.4
# 17962    B-MAX  2014       Manual    40700   Petrol   30  57.7         1.0
# 17963    Focus  2015       Manual     7010   Diesel   20  67.3         1.6
# 17964       KA  2018       Manual     5007   Petrol  145  57.7         1.2
# 17965    Focus  2015       Manual     5007   Petrol   22  57.7         1.0
#
# [17966 rows x 8 columns]

# %%
x_one_encoded=pd.get_dummies(x,drop_first=True)

# %%
x_one_encoded
# Out:
#        year  mileage  tax   mpg  engineSize  model_ C-MAX  model_ EcoSport  \
# 0      2017    15944  150  57.7         1.0         False            False
# 1      2018     9083  150  57.7         1.0         False            False
# 2      2017    12456  150  57.7         1.0         False            False
# 3      2019    10460  145  40.3         1.5         False            False
# 4      2019     1482  145  48.7         1.0         False            False
# ...     ...      ...  ...   ...         ...           ...              ...
# 17961  2017    16700  150  47.1         1.4         False            False
# 17962  2014    40700   30  57.7         1.0         False            False
# 17963  2015     7010   20  67.3         1.6         False            False
# 17964  2018     5007  145  57.7         1.2         False            False
# 17965  2015     5007   22  57.7         1.0         False            False
#
# ...

# %%
x_one_encoded=x_one_encoded.astype(int)

# %%
from sklearn.preprocessing import LabelEncoder

columns = ['model', 'transmission', 'fuelType']
xlabel = x.copy()

encoders = {}
for col in columns:
    le = LabelEncoder()
    xlabel[col] = le.fit_transform(xlabel[col])
    encoders[col] = le

# %%
xlabel
# Out:
#        model  year  transmission  mileage  fuelType  tax   mpg  engineSize
# 0          5  2017             0    15944         4  150  57.7         1.0
# 1          6  2018             1     9083         4  150  57.7         1.0
# 2          6  2017             1    12456         4  150  57.7         1.0
# 3          5  2019             1    10460         4  145  40.3         1.5
# 4          5  2019             0     1482         4  145  48.7         1.0
# ...      ...   ...           ...      ...       ...  ...   ...         ...
# 17961      0  2017             1    16700         4  150  47.1         1.4
# 17962      0  2014             1    40700         4   30  57.7         1.0
# 17963      6  2015             1     7010         0   20  67.3         1.6
# 17964     11  2018             1     5007         4  145  57.7         1.2
# 17965     23  2015             1     5007         4   22  57.7         1.0
#
# [17966 rows x 8 columns]

# %%
xlabel["model"].value_counts()
# Out:
# model
# 5     6557
# 6     4588
# 13    2225
# 2     1143
# 1      543
# 12     531
# 14     526
# 0      355
# 18     296
# 9      247
# 8      228
# 3      208
# 11     199
# 16      80
# 21      69
# 10      59
# 15      57
# 20      33
# 7       16
# 19       2
# 17       1
# 4        1
# 22       1
# 23       1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

x_one_encoded = x.copy()   # start fresh from your original DataFrame

# Label encode categorical columns
cat_cols = ['model', 'transmission', 'fuelType']  # use your actual column names
encoders = {}
for col in cat_cols:
    le = LabelEncoder()
    x_one_encoded[col] = le.fit_transform(x_one_encoded[col].astype(str))
    encoders[col] = le

# Scale numeric columns
num_col = ['year', 'mileage', 'tax', 'mpg', 'engineSize']
sc = StandardScaler()
x_one_encoded[num_col] = sc.fit_transform(x_one_encoded[num_col])

# %%
xlabel.columns
# Out:
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')

# %%
xlabel[['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
       'engineSize']]=sc.fit_transform(xlabel[['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
       'engineSize']])
