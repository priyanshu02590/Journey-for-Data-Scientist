# %%
import pandas as pd

# %%
data={
    "Name":["John","Aman","Peter","Linda"],
    "Age":[19,24,27,34],
    "City":["Delhi","Mumbai","Rajasthan","Up"],
    "Salary":[50000,70000,80000,40000]
}
df=pd.DataFrame(data)
df
# Out:
#     Name  Age       City  Salary
# 0   John   19      Delhi   50000
# 1   Aman   24     Mumbai   70000
# 2  Peter   27  Rajasthan   80000
# 3  Linda   34         Up   40000

# %% [markdown]
# ### Selection and Indexing of Columns

# %%
df["Name"]
# Out:
# 0     John
# 1     Aman
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df[["Name","Age"]]
# Out:
#     Name  Age
# 0   John   19
# 1   Aman   24
# 2  Peter   27
# 3  Linda   34

# %%
df["Designation"]=["Scientist","Doctor","Footballer","Cricketer"]

# %%
df
# Out:
#     Name  Age       City  Salary Designation
# 0   John   19      Delhi   50000   Scientist
# 1   Aman   24     Mumbai   70000      Doctor
# 2  Peter   27  Rajasthan   80000  Footballer
# 3  Linda   34         Up   40000   Cricketer

# %%
df.drop("Designation",axis=1,inplace=True)

# %%
df
# Out:
#     Name  Age       City  Salary
# 0   John   19      Delhi   50000
# 1   Aman   24     Mumbai   70000
# 2  Peter   27  Rajasthan   80000
# 3  Linda   34         Up   40000

# %% [markdown]
# ### Selecting Rows

# %%
df.loc[0:3]
# Out:
#     Name  Age       City  Salary
# 0   John   19      Delhi   50000
# 1   Aman   24     Mumbai   70000
# 2  Peter   27  Rajasthan   80000
# 3  Linda   34         Up   40000

# %%
df.loc[[0,1]][["City","Salary"]]
# Out:
#      City  Salary
# 0   Delhi   50000
# 1  Mumbai   70000

# %%
df.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   27
# 3  Linda   34

# %% [markdown]
# ### Conditional Selection

# %%
df[df["Age"]>20]
# Out:
#     Name  Age       City  Salary
# 1   Aman   24     Mumbai   70000
# 2  Peter   27  Rajasthan   80000
# 3  Linda   34         Up   40000

# %%
df[(df["Age"]>20) & (df["City"] == 'Mumbai')]
# Out:
#    Name  Age    City  Salary
# 1  Aman   24  Mumbai   70000

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
df.groupby("Store")["Sales"].sum()
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
df.groupby(["Category","Store"])["Sales"].sum()
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %%
import numpy as np
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    235     24   John  January      Q1
# 1  2023-01-02       B   West    245     51   Mary  January      Q1
# 2  2023-01-03       C  North    869     91    Bob  January      Q1
# 3  2023-01-04       D  South    775     88  Alice  January      Q1
# 4  2023-01-05       A   East    601     67   John  January      Q1
# 5  2023-01-06       B   West    715     82   Mary  January      Q1
# 6  2023-01-07       C  North    418     23    Bob  January      Q1
# 7  2023-01-08       D  South    437     38  Alice  January      Q1
# 8  2023-01-09       A   East    503     39   John  January      Q1
# 9  2023-01-10       B   West    441     51   Mary  January      Q1
# 10 2023-01-11       C  North    746     83    Bob  January      Q1
# 11 2023-01-12       D  South    734     43  Alice  January      Q1
# 12 2023-01-13       A   East    688     59   John  January      Q1
# 13 2023-01-14       B   West    925     38   Mary  January      Q1
# 14 2023-01-15       C  North    647     49    Bob  January      Q1
# 15 2023-01-16       D  South    152     59  Alice  January      Q1
# 16 2023-01-17       A   East    656     47   John  January      Q1
# 17 2023-01-18       B   West    265     83   Mary  January      Q1
# 18 2023-01-19       C  North    965     36    Bob  January      Q1
# 19 2023-01-20       D  South    544     67  Alice  January      Q1

# %%
pd.pivot_table(df,index="Region",columns="Product",values="Sales")
# Out:
# Product      A      B      C      D
# Region
# East     536.6    NaN    NaN    NaN
# North      NaN    NaN  729.0    NaN
# South      NaN    NaN    NaN  528.4
# West       NaN  518.2    NaN    NaN
