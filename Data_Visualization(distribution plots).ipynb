# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
years=[2005,2006,2007,2008,2009,2010,2011,2012,2014,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025]
goals_scored_by_messi=[6,12,31,22,41,60,59,91,45,58,52,59,54,51,50,27,43,35,28,29,46]
plt.plot(years, goals_scored_by_messi)
plt.xticks(years,rotation=45)
plt.show()

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.scatter(years, goals_scored_by_messi)

# %%
df= sns.load_dataset("tips")

# %%
plt.subplot(2,2,1)
sns.histplot(df["total_bill"],bins=20,kde=True)
plt.subplot(2,2,2)
sns.histplot(df["tip"],bins=20,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="scatter")

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="reg")

# %%
sns.pairplot(df,hue="size")
