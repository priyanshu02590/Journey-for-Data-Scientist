# %% [markdown]
# # Z-Test

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\priyanshu baura\appdata\local\programs\python\python313\lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\priyanshu baura\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.4)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\priyanshu baura\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\priyanshu baura\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\priyanshu baura\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.15.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\priyanshu baura\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np 
from scipy.stats import norm

# %%
sample = [172, 174, 168, 169, 171, 173, 175, 170, 169, 172]
population_mean=170
population_std=3
sample_mean=np.mean(sample)
n=len(sample)
z_score=(sample_mean-population_mean)/(population_std/np.sqrt(n))

# %%
z_score
# Out:
# np.float64(1.3703203194063098)

# %%
p_value=2*(1-norm.cdf(abs(z_score)))

# %%
p_value
# Out:
# np.float64(0.17058693287143756)

# %%
alpha=0.05
if(p_value<alpha):
    print("I will reject the null hypothesis")
else:
    print("I will accept the null hypothesis")
# Out:
# I will accept the null hypothesis

# %% [markdown]
# # T-Test

# %%
from scipy import stats

# %%
sample = [172, 174, 168, 169, 171, 173, 175, 170, 169, 172]
sample_mean=np.mean(sample)
sample_std=np.std(sample,ddof=1)
n=len(sample)
poputlaiton_mean=170

# %%
t_score=(sample_mean-population_mean)/(sample_std/np.sqrt(n))

# %%
t_score
# Out:
# np.float64(1.7782469350914734)

# %%
p_value=2*(1-stats.t.cdf(abs(t_score),df=n-1))

# %%
p_value
# Out:
# np.float64(0.10907771593031335)

# %%
alpha=0.05

# %%
if p_value < alpha:
    print("reject the null hypothesis")
else:
    print("accept the null hypothesis")
# Out:
# accept the null hypothesis
