# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("IPL.csv")

# %%
df.shape
# Out:
# (74, 20)

# %%
df.size
# Out:
# 1480

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
df.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  74.000000         74.000000        74.000000          74.000000
# mean   37.500000        171.121622         6.135135         158.540541
# std    21.505813         29.048355         2.222699          29.299207
# min     1.000000         68.000000         0.000000          72.000000
# 25%    19.250000        154.250000         5.000000         142.750000
# 50%    37.500000        169.500000         6.000000         160.000000
# 75%    55.750000        192.750000         8.000000         176.000000
# max    74.000000        222.000000        10.000000         211.000000
#
#        second_ings_wkts     margin   highscore
# count         74.000000  74.000000   74.000000
# mean           6.175676  16.972973   71.716216
# std            2.639832  19.651047   20.705052
# min            1.000000   2.000000   28.000000
# 25%            4.000000   5.250000   57.000000
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['match_id', 'date', 'venue', 'team1', 'team2', 'stage', 'toss_winner',
#        'toss_decision', 'first_ings_score', 'first_ings_wkts',
#        'second_ings_score', 'second_ings_wkts', 'match_winner', 'won_by',
#        'margin', 'player_of_the_match', 'top_scorer', 'highscore',
#        'best_bowling', 'best_bowling_figure'],
#       dtype='object')

# %%
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
#which team won the most matches
match_wins=df["match_winner"].value_counts()
sns.barplot(y=match_wins.index,x=match_wins.values)
# Out:
# <Axes: ylabel='match_winner'>

# %%
toss_wins=df["toss_winner"].value_counts()
sns.barplot(y=toss_wins.index,x=toss_wins.values)
# Out:
# <Axes: ylabel='toss_winner'>

# %%
t=df["toss_decision"].value_counts()

# %%
t
# Out:
# toss_decision
# Field    59
# Bat      15
# Name: count, dtype: int64

# %%
sns.barplot(x=t.index,y=t.values)
# Out:
# <Axes: xlabel='toss_decision'>

# %%
total_matches=df["match_id"].count()
total_matches
# Out:
# np.int64(74)

# %%
c=df[df["toss_winner"]==df["match_winner"]]["match_id"].count()

# %%
c
per=(36/74)*100
per
# Out:
# 48.64864864864865

# %%
df["won_by"].value_counts()
# Out:
# won_by
# Wickets    37
# Runs       37
# Name: count, dtype: int64

# %%
sns.countplot(x=df["won_by"])
# Out:
# <Axes: xlabel='won_by', ylabel='count'>

# %%
marg=df.groupby("won_by")["margin"].sum()

# %%
marg
# Out:
# won_by
# Runs       1034
# Wickets     222
# Name: margin, dtype: int64

# %%
sns.barplot(x=marg.index,y=marg.values)
# Out:
# <Axes: xlabel='won_by'>

# %%
potm=df["player_of_the_match"].value_counts().head()

# %%
potm
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Name: count, dtype: int64

# %%
sns.barplot(x=potm.values,y=potm.index)
# Out:
# <Axes: ylabel='player_of_the_match'>

# %%
top_scorers=df.groupby("top_scorer")["highscore"].sum()
top_scorers.sort_values(ascending=False,inplace=True)
top_scorers=top_scorers.head(5)
top_scorers
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# KL Rahul           351
# Shubman Gill       288
# Faf du Plessis     257
# Name: highscore, dtype: int64

# %%
sns.barplot(x=top_scorers.values,y=top_scorers.index)
# Out:
# <Axes: ylabel='top_scorer'>

# %%
def wickets(x):
    x=str(x)
    v=x[0]
    v=int(v)
    return v
df["wickets_taken"]=df["best_bowling_figure"].apply(wickets)

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# ...

# %%
bowler=df.groupby("best_bowling")["wickets_taken"].sum().sort_values(ascending=False).head()

# %%
bowler
# Out:
# best_bowling
# Yuzvendra Chahal    17
# Jasprit Bumrah      11
# Kuldeep Yadav       11
# Rashid Khan         11
# Josh Hazlewood      10
# Name: wickets_taken, dtype: int64

# %%
sns.barplot(y=bowler.index,x=bowler.values)
# Out:
# <Axes: ylabel='best_bowling'>

# %%
df[(df["won_by"]=="runs") & (df["margin"].max())]
# Out:
# Empty DataFrame
# Columns: [match_id, date, venue, team1, team2, stage, toss_winner, toss_decision, first_ings_score, first_ings_wkts, second_ings_score, second_ings_wkts, match_winner, won_by, margin, player_of_the_match, top_scorer, highscore, best_bowling, best_bowling_figure, wickets_taken]
# Index: []
#
# [0 rows x 21 columns]
